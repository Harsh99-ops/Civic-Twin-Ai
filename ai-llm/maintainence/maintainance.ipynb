# %%
# !pip install -r requirements.txt

# %%
# !python budget_optimizer.py
# Out:
# Budget: ₹200,000
# Spent: ₹198,360
# Remaining: ₹1,640
# Zones funded: 15 / 50
# Risk addressed: 31.4%
#
# FUNDED (in priority order):
#   [High    ] Waste Management          cost=₹   3,960  risk=56.2
#   [High    ] Streetlight / Electrical  cost=₹   6,200  risk=61.9
#   [High    ] Streetlight / Electrical  cost=₹   6,600  risk=64.8
#   [High    ] Streetlight / Electrical  cost=₹   6,200  risk=57.5
#   [High    ] Streetlight / Electrical  cost=₹   6,200  risk=55.0
#   [High    ] Road Damage               cost=₹  16,200  risk=65.0
#   [High    ] Road Damage               cost=₹  16,200  risk=65.0
#   [High    ] Road Damage               cost=₹  18,600  risk=71.5
#   [High    ] Road Damage               cost=₹  17,400  risk=65.4
#   [High    ] Road Damage               cost=₹  17,400  risk=65.4
#   [High    ] Road Damage               cost=₹  17,400  risk=65.4
#   [High    ] Road Damage               cost=₹  17,400  risk=65.4
# ...

# %%
# !uvicorn api:app --port 8005
# Out:
# INFO:     Started server process [6103]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8005 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [6103]

# %%
# !pip install fastapi uvicorn python-multipart

# %%
# !python risk_engine.py
# Out:
# Top 10 highest-risk zones:
#
#   [Critical] score= 80.2  (28.542, 77.391)  7 complaints, mostly Road Damage
#   [Critical] score= 80.0  (28.572, 77.331)  6 complaints, mostly Drainage / Waterlogging
#   [High    ] score= 71.5  (28.53, 77.394)  4 complaints, mostly Road Damage
#   [High    ] score= 66.6  (28.581, 77.319)  1 complaints, mostly Drainage / Waterlogging
#   [High    ] score= 65.4  (28.572, 77.325)  3 complaints, mostly Road Damage
#   [High    ] score= 65.4  (28.617, 77.373)  3 complaints, mostly Road Damage
#   [High    ] score= 65.4  (28.509, 77.409)  3 complaints, mostly Road Damage
#   [High    ] score= 65.4  (28.566, 77.337)  3 complaints, mostly Road Damage
#   [High    ] score= 65.0  (28.611, 77.394)  2 complaints, mostly Road Damage
#   [High    ] score= 65.0  (28.575, 77.385)  2 complaints, mostly Road Damage

# %%
# !uvicorn api:app --port 8004
# Out:
# INFO:     Started server process [6542]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8004 (Press CTRL+C to quit)
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [6542]

# %%
import subprocess; subprocess.Popen(['uvicorn', 'api:app', '--port', '8004'])
# Out:
# <Popen: returncode: None args: ['uvicorn', 'api:app', '--port', '8004']>

# %%
import time; time.sleep(5); print('ready')
# Out:
# ready

# %%
import requests
response = requests.get('http://127.0.0.1:8004/risk-zones?top_n=10')
print(response.status_code)
print(response.text)
# Out:
# 200
# ...
